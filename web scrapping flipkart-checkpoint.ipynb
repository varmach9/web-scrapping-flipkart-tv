# %%
import csv
from bs4 import BeautifulSoup

# %%
from selenium import webdriver

from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 91.0.4472
# Get LATEST driver version for 91.0.4472
# Driver [C:\Users\lenovo\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache

# %%
url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url)

# %%
def get_urlfrom2to40(no):
    # generate url from search term
    
    template="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}"
    return template.format(str(no))

# %%
get_urlfrom2to40(20)
# Out:
# 'https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=20'

# %%
soup=BeautifulSoup(driver.page_source,"html.parser")

# %%
print(soup.prettify())
# Out:
# <html class="fonts-loaded" lang="en">
#  <head>
#   <script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_mid=36265332332657209011771420173356756563&amp;d_cb=s_c_il%5B0%5D._setAudienceManagerFields" type="text/javascript">
#   </script>
#   <script async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=36265332332657209011771420173356756563" type="text/javascript">
#   </script>
#   <script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields" type="text/javascript">
#   </script>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
# ...

# %%
results=soup.find_all("div",{"class": "_3pLy-c row"})
print(results[0])
# Out:
# <div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">OnePlus Y Series 100 cm (40 inch) Full HD LED Smart Android TV</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTTVSG25MMGB8NKFD8BZ88HR_TVSG25MMGB8NKFD8_"><div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>831 Ratings </span><span class="_13vcmD">&amp;</span><span> 91 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">Netflix|Prime Video|Disney+Hotstar|Youtube</li><li class="rgWa7D">Operating System: Android</li><li class="rgWa7D">Full HD 1920 x 1080 Pixels</li><li class="rgWa7D">20 W Speaker Output</li><li class="rgWa7D">60 Hz Refresh Rate</li><li class="rgWa7D">2 x HDMI | 2 x USB</li><li class="rgWa7D">LED</li><li class="rgWa7D">1 Year Warranty on Product and 1 Year Additional Warranty for Panel</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class=
# ...

# %%
re1=results[0].find("div",{"class":"col col-7-12"})

# %%
re_des=re1.find("div",{"class":"_4rR01T"}).text.strip()
# Out:
# OnePlus Y Series 100 cm (40 inch) Full HD LED Smart Android TV

# %%
re_otherfeat=re1.find("div",{"class":"fMghEO"}).ul.text

# %%
print(re_otherfeat)
# Out:
# Netflix|Prime Video|Disney+Hotstar|YoutubeOperating System: AndroidFull HD 1920 x 1080 Pixels20 W Speaker Output60 Hz Refresh Rate2 x HDMI | 2 x USBLED1 Year Warranty on Product and 1 Year Additional Warranty for Panel

# %%
re2=results[0].find("div",{"class":"col col-5-12 nlI3QM"})

# %%
print(re2)
# Out:
# <div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹23,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->27,999</div><div class="_3Ay6Sb"><span>14% off</span></div></div></div><div class="_13J9qT"><img height="21" src="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/img/fa_62673a.png"/></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#26A541;font-size:14px;font-style:normal;font-weight:400">Bank Offer</div></div></div><div class="_2ZdXDB"><div class="_3xFhiH"><div class="_2Tpdn3 _18hQoS" style="color:#000000;font-size:12px;font-style:normal;font-weight:400">No Cost EMI</div></div></div></div>

# %%
re2.div.text.strip()
# Out:
# '₹23,999₹27,99914% off'

# %%
import csv
from bs4 import BeautifulSoup
from selenium import webdriver

from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

url="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
driver.get(url)
def get_urlfrom2to40(no):
    # generate url from search term
    
    template="https://www.flipkart.com/search?q=tv&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page={}"
    return template.format(str(no))
soup=BeautifulSoup(driver.page_source,"html.parser")
results=soup.find_all("div",{"class": "_3pLy-c row"})
re1=results[i].find("div",{"class":"col col-7-12"})
re_des=re1.find("div",{"class":"_4rR01T"}).text.strip()
re_otherfeat=re1.find("div",{"class":"fMghEO"}).ul.text
re2=results[i].find("div",{"class":"col col-5-12 nlI3QM"})
re_priceanddis=re2.div.text.strip()
